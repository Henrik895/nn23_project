# %%
from google.colab import drive

# %%
# !git clone https://github.com/ultralytics/yolov5.git -q

# %%
# !pip install -r yolov5/requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.2 MB/s eta 0:00:00

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q drive/MyDrive/data.zip

# %%
# !python yolov5/train.py --weights yolov5m6.pt --data unit_symbols.yaml --workers 4 --batch-size 16 --epochs 30 --img 1000
# Out:
# train: weights=yolov5m6.pt, cfg=, data=unit_symbols.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=1000, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=4, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-166-g54e9515 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python yolov5/val.py --weights yolov5/runs/train/exp2/weights/best.pt --data unit_symbols.yaml --img 1000
# Out:
# val: data=unit_symbols.yaml, weights=['yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=1000, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-166-g54e9515 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 276 layers, 35306640 parameters, 0 gradients, 49.0 GFLOPs
# WARNING ⚠️ --img-size 1000 must be multiple of max stride 64, updating to 1024
# val: Scanning /content/data/labels/val.cache... 200 images, 0 backgrounds, 0 corrupt: 100% 200/200 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:14<00:00,  2.03s/it]
#                    all        200        443      0.999          1      0.995      0.982
# ...

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp2/weights/best.pt --source data/images/test
# Out:
# detect: weights=['yolov5/runs/train/exp2/weights/best.pt'], source=data/images/test, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-166-g54e9515 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 276 layers, 35306640 parameters, 0 gradients, 49.0 GFLOPs
# image 1/200 /content/data/images/test/img0.jpg: 512x640 1 armour, 59.2ms
# image 2/200 /content/data/images/test/img1.jpg: 512x640 2 anti_tanks, 1 armour, 24.9ms
# image 3/200 /content/data/images/test/img10.jpg: 512x640 2 anti_tanks, 1 armour, 24.8ms
# ...
